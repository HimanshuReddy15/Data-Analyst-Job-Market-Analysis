# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\91944\Downloads\dataAnalystJobsIndia_7th_July_2024 4 1.csv")

# %%
df
# Out:
#                                               job_title  \
# 0       JP Morgan Chase - Client Data Analyst (4-8 yrs)
# 1                              Data Analyst - Bangalore
# 2     Senior IT ATLAS Data Analyst and Integration S...
# 3                               Consultant Data Analyst
# 4              Senior Data Analyst - Retail Liabilities
# ...                                                 ...
# 1484                                       Data Analyst
# 1485                          Data Analyst - Technology
# 1486                Reliability Data Analyst - RVR & JC
# 1487                                      Data Analysts
# 1488                                       Data analyst
#
#                        company experience  min exp  max exp        salary  \
# 0              JP Morgan Chase    4-8 Yrs      4.0      8.0           NaN
# 1           Schneider Electric   5-10 Yrs      5.0     10.0  ₹ 8 - 16L/yr
# ...

# %%
df['details'].isnull(). values. any()
# Out:
# True

# %%
df.isnull().loc[180,'details']
# Out:
# True

# %%
df.loc[180,'details']
# Out:
# nan

# %%
for i in range(1488):
    if df.isnull().loc[i,'details']:
         df.loc[i,'details'] = df.loc[i,'job_title']
    else:
        continue

# %%
df.loc[180,'details']
# Out:
# 'Data Analyst'

# %%
df['job_title'] = "Data Analysts"

# %%
df['experience'] = df['experience'].fillna('No Experience Required')

# %%
df['min exp'] = df['min exp'].fillna('0')
df['max exp'] = df['max exp'].fillna('0')
df
# Out:
#           job_title                   company experience min exp max exp  \
# 0     Data Analysts           JP Morgan Chase    4-8 Yrs     4.0     8.0
# 1     Data Analysts        Schneider Electric   5-10 Yrs     5.0    10.0
# 2     Data Analysts  SAP Labs India Pvt. Ltd.   7-11 Yrs     7.0    11.0
# 3     Data Analysts                    Pfizer    2-6 Yrs     2.0     6.0
# 4     Data Analysts           IDFC FIRST Bank   5-10 Yrs     5.0    10.0
# ...             ...                       ...        ...     ...     ...
# 1484  Data Analysts      Augmenter Consulting    2-5 Yrs     2.0     5.0
# 1485  Data Analysts             Vayaa Systems    1-3 Yrs     1.0     3.0
# 1486  Data Analysts               PinnacleART    1-7 Yrs     1.0     7.0
# 1487  Data Analysts               MightyMorse    1-4 Yrs     1.0     4.0
# 1488  Data Analysts                   Zecotok    1-3 Yrs     1.0     3.0
#
#             salary  base salary  max salary  \
# 0              NaN          NaN         NaN
# ...

# %%
df['min exp'] = df['min exp'].astype(int)
df['max exp'] = df['max exp'].astype(int)
df['jobListed(days ago)'] = df['jobListed(days ago)'].astype(int)

# %%
print(df.dtypes)
# Out:
# job_title                  object
# company                    object
# experience                 object
# min exp                     int32
# max exp                     int32
# salary                     object
# base salary               float64
# max salary                float64
# location                   object
# jobListed(days ago)         int32
# postedIn                   object
# rating                    float64
# reviews count             float64
# details                    object
# salary data provide by     object
# dtype: object

# %%
df['details'].isnull().values.any()
# Out:
# False

# %%
pd.set_option('display.max_rows',None)

# %%
df[['salary','salary data provide by']]
# Out:
#                                           salary     salary data provide by
# 0                                            NaN                        NaN
# 1                                   ₹ 8 - 16L/yr   Salary Listed by Company
# 2                                            NaN                        NaN
# 3                                            NaN                        NaN
# 4                                            NaN                        NaN
# 5                                            NaN                        NaN
# 6                                            NaN                        NaN
# 7                                            NaN                        NaN
# 8                                            NaN                        NaN
# 9                                            NaN                        NaN
# 10                                           NaN                        NaN
# ...

# %%
df[['salary','del']] = df['salary'].str.split('(',expand=True)

# %%
pd.set_option('display.max_columns',None)

# %%
df = df.drop('del',axis=1)

# %%
df_exploded = df.assign(location=df['location'].str.split(',')).explode('location')

# %%
df_exploded['location']=df_exploded['location'].str.replace('\t+1 more',"")

# %%
df_exploded[['skill1','skill2','skill3']] = df_exploded['details'].str.split(',',expand=True)

# %%
df_exploded.dtypes
# Out:
# job_title                  object
# company                    object
# experience                 object
# min exp                     int32
# max exp                     int32
# salary                     object
# base salary               float64
# max salary                float64
# location                   object
# jobListed(days ago)         int32
# postedIn                   object
# rating                    float64
# reviews count             float64
# details                    object
# salary data provide by     object
# skill1                     object
# skill2                     object
# skill3                     object
# dtype: object

# %%
df1 = df_exploded.drop('details',axis=1)

# %%
df1
# Out:
#           job_title                                            company  \
# 0     Data Analysts                                    JP Morgan Chase
# 1     Data Analysts                                 Schneider Electric
# 1     Data Analysts                                 Schneider Electric
# 2     Data Analysts                           SAP Labs India Pvt. Ltd.
# 3     Data Analysts                                             Pfizer
# 4     Data Analysts                                    IDFC FIRST Bank
# 5     Data Analysts                                    JP Morgan Chase
# 6     Data Analysts            GlaxoSmithKline Pharmaceuticals Limited
# 7     Data Analysts                                       Walmart Labs
# 8     Data Analysts                                    Hewlett-Packard
# 9     Data Analysts                                    IDFC FIRST Bank
# 9     Data Analysts                                    IDFC FIRST Bank
# ...

# %%
df1['salary'] = df1['salary'].str.replace('₹','')

# %%
df2 = df1.reset_index()

# %%
df2 = df2.drop('index',axis=1)

# %%
df2.to_csv(r'C:\Users\91944\OneDrive\Desktop\Experiment\DataAnalyst_Market.csv',index = True)
